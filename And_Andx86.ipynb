# %%
#Termux
termuxdir="/data/data/com.termux/files/home"
rundir=$(termuxdir)/.termux/boot/run.sh
printf "
termux-wake-lock \
$(termuxdir)/start-andronix.sh \
node-red & \
" | tsudo tee $(rundir)


termuxdir="/data/data/com.termux/files/home"
rundir="$termuxdir/.termux/boot/run.sh"
cat <<EOF > $rundir
#!/bin/bash
termux-wake-lock
$termuxdir/start-andronix.sh
node-red &
EOF
chmod +x $rundir



termux-wake-lock
node-red &
./start-kali.sh &
am start com.realvnc.viewer.android/.app.ConnectionChooserActivity

# %%
#Andronix_Ubuntu
pkg install wget openssl-tool proot tar -y && hash -r && wget https://raw.githubusercontent.com/Techriz/AndronixOrigin/master/Installer/Ubuntu/ubuntu.sh && bash ubuntu.sh
apt install wget && wget https://raw.githubusercontent.com/Techriz/AndronixOrigin/master/APT/XFCE4/xfce4_de.sh && bash xfce4_de.sh

# %%
#AndroidQ_DesktopMode
am start -n "com.google.android.apps.nexuslauncher/com.android.launcher3.SecondaryDisplayLauncher"

# %%
#Andronix_Kali_WORKING
command+=" -b /sdcard/00noderedflows/Kali/.config.json:/root/.node-red/.config.json"
command+=" -b /sdcard/00noderedflows/Kali/.config.json.backup:/root/.node-red/.config.json.backup"
command+=" -b /sdcard/00noderedflows/Kali/.flows.json.backup:/root/.node-red/.flows.json.backup"
command+=" -b /sdcard/00noderedflows/Kali/flows.json:/root/.node-red/flows.json"
command+=" -b /sdcard/00noderedflows/Kali/package-lock.json:/root/.node-red/package-lock.json"
command+=" -b /sdcard/00noderedflows/Kali/package.json:/root/.node-red/package.json"
command+=" -b /sdcard/00noderedflows/Kali/settings_ori.js:/root/.node-red/settings_ori.js"
command+=" -b /sdcard/00noderedflows/Kali/settings.js:/root/.node-red/settings.js"


command+=" -b /sdcard/00noderedflows/Kali/.config.json:/root/.node-red/.config.json" \
command+=" -b /sdcard/00noderedflows/Kali/.config.json.backup:/root/.node-red/.config.json.backup" \
command+=" -b /sdcard/00noderedflows/Kali/.flows.json.backup:/root/.node-red/.flows.json.backup" \
command+=" -b /sdcard/00noderedflows/Kali/flows.json:/root/.node-red/flows.json" \
command+=" -b /sdcard/00noderedflows/Kali/package-lock.json:/root/.node-red/package-lock.json" \
command+=" -b /sdcard/00noderedflows/Kali/package.json:/root/.node-red/package.json" \
command+=" -b /sdcard/00noderedflows/Kali/settings_ori.js:/root/.node-red/settings_ori.js" \
command+=" -b /sdcard/00noderedflows/Kali/settings.js:/root/.node-red/settings.js"


#uninstall
pkg install wget openssl-tool proot tar -y && hash -r && wget https://raw.githubusercontent.com/Techriz/AndronixOrigin/master/Uninstall/Kali/UNI-kali.sh && bash UNI-kali.sh

#install
pkg install wget openssl-tool proot tar -y && hash -r && wget https://raw.githubusercontent.com/Techriz/AndronixOrigin/master/Installer/Kali/kali.sh && bash kali.sh


#OUTSIDEKALI
apt install -y termux-api

nano ./start-kali.sh
file=/data/data/com.termux/files/home/start-kali.sh
#1
cp "$file" "$file".backup

#2 findthis
find0='#command+=" -b /sdcard"'
#replace " with \"
find1=$(echo $find0 | sed -e 's/\"/\\\"/g')
#replace / with \/
find=$(echo $find1 | sed -e 's/\//\\\//g')

#2 repwith
rep0='command+=" -b /sdcard:/root/Desktop/ext" \
command+=" -b /sdcard/0Anki2:/root/.local/share/Anki2"'
#replace \ with \n
rep1=$(echo $rep0 | sed -e 's/\\/\\n/g')
#replace " with \"
rep2=$(echo $rep1 | sed -e 's/\"/\\\"/g')
#replace / with \/
rep=$(echo $rep2 | sed -e 's/\//\\\//g')

#3 sed
#sed -e "s/$find/$rep/g" $file
sed -i "s/$find/$rep/g" $file
##sed -e '/s'$find'/'$rep'/g' $filesed -e 's/#command+=\" -b \/sdcard\"/command+=\" -b \/sdcard:\/root\/Desktop\/ext\"\ncommand+=\" -b \/sdcard\/0Anki2:\/root\/.local\/share\/Anki2\"/g' /data/data/com.termux/files/home/start-kali.sh
#cp "$file".backup "$file"

./start-kali.sh

#INSIDEKALI
apt update
#apt upgrade -y
apt install -y sudo nano build-essential git curl wget apt-utils procps
apt install -y tightvncserver
apt install -y anki python3-distutils
#anki --no-sandbox

apt install -y nodejs npm
npm install -g webdriver-manager
#bash <(curl -sL https://raw.githubusercontent.com/node-red/linux-installers/master/deb/update-nodejs-and-nodered)

sudo npm install -g --unsafe-perm node-red
#node-red &
#chromium --no-sandbox localhost:1880 &

sudo vncserver
#qwerty
#qwerty

apt install -y wget && wget https://raw.githubusercontent.com/Techriz/AndronixOrigin/master/APT/XFCE4/xfce4_de.sh && bash xfce4_de.sh


file=/usr/local/bin/vncserver-start
cat $file
#nano $file
#1
cp "$file" "$file".backup


#2 findthis
find0="-name"
#replace " with \"
find1=$(echo $find0 | sed -e 's/\"/\\\"/g')
#replace / with \/
find=$(echo $find1 | sed -e 's/\//\\\//g')

#2 repwith
rep0="-geometry 820x1664 -name"
#replace \ with \n
rep1=$(echo $rep0 | sed -e 's/\\/\\n/g')
#replace " with \"
rep2=$(echo $rep1 | sed -e 's/\"/\\\"/g')
#replace / with \/
rep=$(echo $rep2 | sed -e 's/\//\\\//g')

#3 sed
#sed -i 's//-geometry 820x1664/g' /usr/local/bin/vncserver-start
#sed -e "s/$find/$rep/g" $file
sed -i "s/$find/$rep/g" $file



#nano ~/.bash_profile
printf "sudo kill $(ps -ef | grep Xtightvnc | awk 'NR==1{print $2}' )\n
vncserver-stop \n
rm -f /tmp/.X11-unix/X1 \n
rm -f /tmp/.X1-lock \n
vncserver-start \n
#startxfce4 & \n
#xfwm4 & \n
node-red & \n
anki --no-sandbox &" | sudo tee -a ~/.bash_profile

#curl -sL https://deb.nodesource.com/setup_10.x | sudo -E bash -
#curl -sL https://deb.nodesource.com/setup_12.x | sudo -E bash -
sudo apt-get update
sudo apt-get install -y git-core curl build-essential openssl libssl-dev python
git clone https://github.com/nodejs/node.git
cd node

./configure
make
sudo make install

curl -L https://npmjs.org/install.sh | sudo sh
npm -v



sudo rm -rf /usr/local/bin/npm /usr/local/share/man/man1/node* ~/.npm
sudo rm -rf /usr/local/lib/node*
sudo rm -rf /usr/local/bin/node*
sudo rm -rf /usr/local/include/node*

sudo apt-get purge nodejs npm
sudo apt autoremove

#https://nodejs.org/en/download/
wget https://nodejs.org/dist/v12.16.1/node-v12.16.1-linux-x64.tar.xz
tar -xf node-v*-linux-x64.tar.xz
sudo mv node-v*-linux-x64/bin/* /usr/local/bin/
sudo mv node-v*-linux-x64/lib/node_modules/ /usr/local/lib/

curl -o- https://raw.githubusercontent.com/creationix/nvm/v0.33.0/install.sh | bash
export NVM_DIR="/root/.nvm"



#anki.desktop
file=~/.config/autostart/anki.desktop
printf "[Desktop Entry] \n
Encoding=UTF-8 \n
Version=0.9.4 \n
Type=Application \n
Name=anki \n
Comment= \n
Exec=xfce4-terminal -e \"anki --no-sandbox &\" \n
OnlyShowIn=XFCE; \n
StartupNotify=false \n
Terminal=false \n
Hidden=false" | sudo tee $file

su -c "input text 'printf \"[Desktop Entry] \n Encoding=UTF-8 \n Version=0.9.4 \n Type=Application \n Name=anki \n Comment= \n Exec=xfce4-terminal -e \\\"anki --no-sandbox &\\\" \n OnlyShowIn=XFCE; \n StartupNotify=false \n Terminal=false \n Hidden=false\" | sudo tee -a ~/.config/autostart/anki.desktop.2'"

su -c "input text 'printf \"[Desktop Entry] \n Encoding=UTF-8 \n Version=0.9.4 \n Type=Application \n Name=anki \n Comment= \n Exec=xfce4-terminal -e \\\"anki --no-sandbox &\\\" \n OnlyShowIn=XFCE; \n StartupNotify=false \n Terminal=false \n Hidden=false\" | sudo tee -a ~/.config/autostart/anki.desktop.2'"


printf "[Desktop Entry] \n Encoding=UTF-8 \n Version=0.9.4 \n Type=Application \n Name=anki \n Comment= \n Exec=xfce4-terminal -e \"anki --no-sandbox &\" \n OnlyShowIn=XFCE; \n StartupNotify=false \n Terminal=false \n Hidden=false" | sudo tee -a ~/.config/autostart/anki.desktop.

# %%
#Andronix
#ubuntuxfce
pkg install curl -y && token="kSx7YV6nJR0QgxMt6FOpwlmgiptM4fNpOL5c4uss7n5h20FOcwwatyIVIu7spmGg" bash <(curl -s https://andronixos.sfo2.digitaloceanspaces.com/ModdedV2/andronix.sh)
wget https://andronixos.sfo2.digitaloceanspaces.com/ModdedV2/andronix_uninstall.sh && chmod +x andronix_uninstall.sh && bash andronix_uninstall.sh

#debianxfce
#install
pkg install curl -y && token="GPdqYZdiiZ8w5NlNo0jAnqMQeUKlulkDMkspECY4wlQkA8AK3BCwGwSkOnxWiTW2" bash <(curl -s https://andronixos.sfo2.digitaloceanspaces.com/ModdedV2/deb_mod.sh) 
#uninstall
wget https://andronixos.sfo2.digitaloceanspaces.com/ModdedV2/debmod_uninstall.sh && chmod +x debmod_uninstall.sh && bash debmod_uninstall.sh

#And_LD_Bionic18.04
#And_LD_Xenial16.04
sudo apt-get update
#general
sudo apt-get install -y software-properties-common apt-utils build-essential gedit make

# %%
#node-red
bash <(curl -sL https://raw.githubusercontent.com/node-red/linux-installers/master/deb/update-nodejs-and-nodered)
node-red-start

# %%
#anki
#sudo apt-get install -y snapd
#sudo snap install anki-woodrow
sudo apt-get install -y anki python3-distutils
sudo apt-get install -y anki python3-distutils-extra
#ANKI2
sudo apt install make
tar xjf ~/Downloads/anki*.tar.bz2
cd ~/Downloads/anki*
sudo make install

#xdg-mime fix
sudo apt-get install xdg-utils --fix-missing

#Anki requires a UTF-8 locale
sudo apt-get install -y language-pack-en-base locales
sudo update-locale LANG=en_US.utf8
export LC_CTYPE=en_US.UTF-8
sudo locale-gen en_US en_US.UTF-8
sudo dpkg-reconfigure locales
#158
#3


#UserLand_Android_Bionic18.04
Sudo sed -i 's|#x-window-manager &|#x-window-manager -geometry 1770x720 &|g' /home/user/.vnc/xstartup
Sudo mount -t /host-rootfs/storage/emulated/0/0Anki2 /home/user/.local/share/Anki2
Sudo mount -t /host-rootfs/storage/emulated/0/0Anki2 /home/user/.local/share/Anki2

# %%
#firefox
sudo add-apt-repository ppa:mozillateam/ppa -y
sudo apt-get update
sudo apt-get install -y firefox-esr
#sudo apt-get install -y chromium-browser
sudo apt-get install --reinstall xserver-xorg-input-all -y

# %%
#Start-kali.sh
nano ~/.bash_profile

vncserver-stop
rm -f /tmp/.X11-unix/X1
rm -f /tmp/.X1-lock
vncserver-start
anki --no-sandbox

# %%
#androidx86
#cd /system/xbin && mv su su.bak
#https://www.youtube.com/watch?v=4wG4OMnB0V4
.\mkbootimg --kernel kernel --ramdisk ramdisk.img --second initrd.img --output boot.img
cp boot.img-ramdisk.cpio.gz ramdisk.img
cp boot.img-zImage kernel
cp boot.img-second initrd.img

cp magisk_patched.img-ramdisk.cpio.gz ramdisk.img
cp magisk_patched.img-zImage kernel
cp magisk_patched.img-second initrd.img

# %%
#NR_Install_Androidx86
apt update
#apt upgrade
apt install -y coreutils nano nodejs termux-api
npm i -g --unsafe-perm node-red
node-red &

#ubuntubionickey
sudo apt-key adv --keyserver hkp://keyserver.ubuntu.com:80 --recv-keys 3B4FE6ACC0B21F32
apt update
