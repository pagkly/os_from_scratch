# %%
#MacOSInstall
#csrutil disable
#download :
#https://reddit.com/sjainguides
#https://nmac.to
#http://stevenygard.com/projects/class-dump/
#https://uploaded.net/file/vfe8zv97/nmac.to_tsin201.zip
#http://uploaded.net/file/vrhdj06h/nmac.to_flext14.zip
#activity timer

#http://ezine.echo.or.id/ezine22/e22-005.txt
#https://lifehacker.com/how-to-crack-just-about-any-mac-app-and-how-to-prevent-5736101
#http://loadcode.blogspot.com/2006/02/cracking-software-on-os-x.html
#https://iichamp.wordpress.com/2014/03/05/how-to-reset-trail-programs-on-mac/
#https://news.ycombinator.com/item?id=2113236
#install office
#install acrobat pro dc

#Settings :
#show path bar
#show drive
sudo spctl --master-disable
xcode-select --install
/usr/bin/ruby -e "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install)"

#https://aspiceodyssey.wordpress.com/2017/12/01/building-spice-client-for-macos/
brew cask install clover-configurator
brew cask install teamviewer
brew cask install chrome-remote-desktop-host
brew cask install google-chrome
brew cask install vivaldi
brew cask install vlc
brew cask install spotify
brew cask install caffeine
brew cask install otx
brew cask install macs-fan-control
brew cask install visual-studio-code
brew cask install chromedriver
#brew cask install atom
#brew install qt-virt-manager
brew install spice-protocol
brew install spice-gtk
brew install selenium-server-standalone

brew install wget 
brew install curl 
brew install p7zip
brew cask install class-dump
cp /usr/local/bin/class-dump

Non:
mkdir homebrew && curl -L https://github.com/Homebrew/brew/tarball/master | tar xz --strip 1 -C homebrew
brew cask install michaelvillar-timer

#Spiceagent (clipboard for macos)
#https://aspiceodyssey.wordpress.com/2017/12/01/building-spice-client-for-macos/
/usr/bin/ruby -e "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install)"
brew install pkg-config gettext intltool pixman gtk+3 gtk-doc gstreamer gstreamermm libjpeg-turbo gst-plugins-good gst-plugins-bad gst-libav
brew cask install xquartz
cd ~
git clone https://github.com/c3d/spice
cd spice
export PKG_CONFIG_PATH=/usr/local/opt/jpeg-turbo/lib/pkgconfig:/usr/local/Cellar/openssl/1.0.2m/lib/pkgconfig:$PKG_CONFIG_PATH
make -j
./spicy -h some-host -p 5900
#HACKINTOSH
#DONE
#KEXTS
#https://onedrive.live.com/?authkey=!APjCyRpzoAKp4xs&id=FE4038DA929BFB23!455036&cid=FE4038DA929BFB23
#https://github.com/Broly1/Hackintosh-linux-Installer
#https://hackintosh.gitbook.io/-r-hackintosh-vanilla-desktop-guide/config.plist-basics
#https://github.com/myspaghetti/macos-virtualbox
#https://github.com/foxlet/macOS-Simple-KVM
#https://github.com/kholia/OSX-KVM
#https://www.youtube.com/watch?v=vXMNyiEgD6o

# %%
#HACKINTOSH
#FLASH
#https://hackintosh.gitbook.io/-r-hackintosh-vanilla-desktop-guide/config.plist-per-hardware/coffee-lake#explanation-4
#https://hackintosher.com/guides/guide-to-fresh-installing-macos-mojave-on-a-hackintosh-10-14/
cd ~
cd gibMacOS
sudo ./gibMacOS.command -R
sudo ./finalflash.sh
#/home/$USER/gibMacOS/macOS Downloads/publicrelease/061-86291 - 10.15.3 macOS Catalina/BaseSystem.dmg
#/home/user/gibMacOS/macOS Downloads/publicrelease/061-86291 - 10.15.3 macOS Catalina
#/home/user/gibMacOS/macOS Downloads/publicrelease/001-04366 - 10.15.4 macOS Catalina

cp finalflash.sh


cd ~
git clone https://github.com/corpnewt/ProperTree
cd ProperTree
sed -i "s|env python|env python3|g" ProperTree.command
sudo apt install -y python3-tk
sudo chmod u+x ProperTree.command
./ProperTree.command


#MANUAL
sudo gparted


cd ~
git clone https://github.com/acidanthera/OpenCorePkg/releases
https://dortania.github.io/OpenCore-Desktop-Guide/

sudo nautilus EFI/CLOVER/drivers/UEFI

# %%
#RTL8812BU
#https://www.fastoe.com/downloads/ac1300-usb-wifi-adapter
git clone https://github.com/fastoe/RTL8812BU/releases/download/20200414/rtl88x2BU_macos_10.6-10.15.zip
7z x rtl88x2BU*.zip  -o*

# %%
#Mount EFI
#convert clover to OpenCore
#Mount OpenCore.qcow2
#https://unix.stackexchange.com/questions/268460/how-to-mount-qcow2-image
#Step 1 - Enable NBD on the host
sudo modprobe nbd max_part=8
#Step 2 - Connect the QCOW2 as a network block device
sudo qemu-nbd --connect=/dev/nbd0 /media/user/SED/VBOX/GitHub/OpenCore.qcow2
#Step 3 - List partitions inside the QCOW2
sudo fdisk /dev/nbd0 -l
#Step 4 - Mount the partition from the VM
sudo mount /dev/nbd0p1 ~/Documents/ESP0
sudo cp -r ~/Documents/ESP0/* /mnt/

#unmount all
sudo umount /mnt/
sudo umount ~/Documents/ESP0
